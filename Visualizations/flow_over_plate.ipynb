# %%
## import  modules
import numpy as np
import matplotlib.pyplot as plt

# %%
a=np.linspace(-5,5,101)
b=np.linspace(0,1,11)

x,y=np.meshgrid(a,b)
c=4/3
u= c*y - y**c ## velocity profile
plt.figure(figsize=(10,1.5))
plt.contour(u,900,cmap="jet")
plt.show()
